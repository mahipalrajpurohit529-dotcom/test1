# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\asus\Downloads\credit_scoring - credit_scoring.csv")

# %%
df.head()
# Out:
#    Age  Gender Marital Status Education Level Employment Status  \
# 0   60    Male        Married          Master          Employed
# 1   25    Male        Married     High School        Unemployed
# 2   30  Female         Single          Master          Employed
# 3   58  Female        Married             PhD        Unemployed
# 4   32    Male        Married        Bachelor     Self-Employed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22             2685                          2
# 1                      0.20             2371                          9
# 2                      0.22             2771                          6
# 3                      0.12             1371                          2
# 4                      0.99              828                          2
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        1000 non-null   int64
#  1   Gender                     1000 non-null   object
#  2   Marital Status             1000 non-null   object
#  3   Education Level            1000 non-null   object
#  4   Employment Status          1000 non-null   object
#  5   Credit Utilization Ratio   1000 non-null   float64
#  6   Payment History            1000 non-null   int64
#  7   Number of Credit Accounts  1000 non-null   int64
#  8   Loan Amount                1000 non-null   int64
#  9   Interest Rate              1000 non-null   float64
#  10  Loan Term                  1000 non-null   int64
#  11  Type of Loan               1000 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 93.9+ KB

# %%
# df.isna().sum()

# %%
x = df.drop(columns=['Type of Loan'])
y = df['Type of Loan']

# %%
num_df = x.select_dtypes(exclude='object').columns
cat_df = x.select_dtypes(include='object').columns

# %%
num_df
# Out:
# Index(['Age', 'Credit Utilization Ratio', 'Payment History',
#        'Number of Credit Accounts', 'Loan Amount', 'Interest Rate',
#        'Loan Term'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1',StandardScaler(),num_df),
    ('tnf2',OneHotEncoder(handle_unknown='ignore'),cat_df)
],remainder='passthrough')

# %%
transformer.fit_transform(x_train).shape
# Out:
# (800, 19)
